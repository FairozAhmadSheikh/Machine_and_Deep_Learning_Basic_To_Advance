# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[v**2 for v in x ]

# %%
plt.plot(x,y)

# %% [markdown]
# some methods for plotting
# # Method 1

# %%
fig=plt.figure()
ax=fig.add_subplot()
ax.plot(x,y)
plt.show()

# %% [markdown]
# Method 2

# %%
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show();

# %% [markdown]
# But we will be using `Method 3`

# %% [markdown]
# ### Method 3  recomended by matplotlib also known as Object Oriented Method

# %%
fig,ax=plt.subplots()
ax.plot(x,y)
ax.set(title="Simple Line graph",
       xlabel='number',
       ylabel='square');

# %%
# save plots
fig.savefig("saved_figure_line_plot_square_and_number.png")

# %% [markdown]
# WE WILL MAINLY COVER
#     `Line PLot`
#     `Bar Plot`
#     `Scatter Plot`
#     `Histogram`
#     `Subplots`

# %%
import numpy as np
x=np.linspace(0,10,40)

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2)  # Line PLot
ax.set(title="Numbers and ssquare",
       xlabel='Numbers',
       ylabel='Squared')
# Out:
# [Text(0.5, 1.0, 'Numbers and ssquare'),
#  Text(0.5, 0, 'Numbers'),
#  Text(0, 0.5, 'Squared')]

# %%
# Scatter Plot 
x=np.linspace(0,100,10)
fig,ax=plt.subplots(figsize=(2,2))
ax.scatter(x,x**2)

# %%
fig,ax=plt.subplots(figsize=(2,2))
ax.plot(x,np.cos(x))

# %% [markdown]
# # Making plots from dictionaries

# %%
car_prices={
    "creta":10,
    "scorpio":15,
    "breeza":16,
}
fig,ax=plt.subplots(figsize=(3,3))
ax.bar(car_prices.keys(),car_prices.values())
ax.set(title='Prices of cars',
       xlabel="Car Model",
       ylabel="Car Price")
ax.plot();

# %%
# Horizontal bar graph requires data in list
fig,ax=plt.subplots(figsize=(3,3))
ax.barh(list(car_prices.keys()),list(car_prices.values()))
ax.set(title="Prices of cars and values",
       ylabel="carname",
       xlabel='prices ($)')
# Out:
# [Text(0.5, 1.0, 'Prices of cars and values'),
#  Text(0, 0.5, 'carname'),
#  Text(0.5, 0, 'prices ($)')]

# %% [markdown]
# ## Histogram

# %%
x=np.random.randn(100000)
fig,ax=plt.subplots(figsize=(5,5))
ax.hist(x);

# %% [markdown]
# #  Two Options for subplots

# %%
# Method 1 : preferd method
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,
                                       ncols=2,
                                       figsize=(10,5))
ax1.plot(x,x/2);
ax2.scatter(np.random.randint(10),np.random.randint(10));
ax3.barh(list(car_prices.keys()),list(car_prices.values()));
ax4.hist(np.random.randn(1000));

# %%
# Method 2 of plotting 
fix,ax=plt.subplots(nrows=2,
                     ncols=2,
                    figsize=(8,8))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(car_prices.keys(),car_prices.values());
ax[1,1].hist(np.random.randn(10000));

# %% [markdown]
# # lets now create the same using DataFrames

# %%
import pandas as pd
car_price=pd.read_csv("https://raw.githubusercontent.com/FairozAhmadSheikh/Datasets_CSV/refs/heads/main/Car%20Price.csv")

# %%
car_price.head()
# Out:
#      Brand                     Model  Year  Selling_Price  KM_Driven    Fuel  \
# 0   Maruti             Maruti 800 AC  2007          60000      70000  Petrol
# 1   Maruti  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2  Hyundai      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3   Datsun    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4    Honda     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   Seller_Type Transmission         Owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
# Lets first plot using a series
ts=pd.Series(np.random.random(1000),index=pd.date_range("01/01/2025",periods=1000))

# %%
ts[:10]
# Out:
# 2025-01-01    0.707032
# 2025-01-02    0.218924
# 2025-01-03    0.137929
# 2025-01-04    0.116043
# 2025-01-05    0.662396
# 2025-01-06    0.852374
# 2025-01-07    0.226862
# 2025-01-08    0.932613
# 2025-01-09    0.158568
# 2025-01-10    0.011854
# Freq: D, dtype: float64

# %%
ts.plot();

# %%
car_price.head()
# Out:
#      Brand                     Model  Year  Selling_Price  KM_Driven    Fuel  \
# 0   Maruti             Maruti 800 AC  2007          60000      70000  Petrol
# 1   Maruti  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2  Hyundai      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3   Datsun    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4    Honda     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   Seller_Type Transmission         Owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
car_price['Seller_Type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %% [markdown]
# # Finding only those who are Trustmark dealers

# %%
car_price[car_price["Seller_Type"]=="Trustmark Dealer"]
# Out:
#          Brand                            Model  Year  Selling_Price  \
# 540     Maruti            Maruti Swift ZXI BSIV  2016         670000
# 541     Maruti  Maruti S-Cross Zeta DDiS 200 SH  2015         750000
# 542    Hyundai        Hyundai Verna 1.6 VTVT SX  2015         760000
# 544    Renault                Renault Pulse RxL  2015         390000
# 545     Maruti      Maruti Celerio VXI AMT BSIV  2016         450000
# ...        ...                              ...   ...            ...
# 4096  Mahindra   Mahindra XUV500 W10 1.99 mHawk  2016        1250000
# 4097    Maruti           Maruti Baleno Zeta 1.2  2017         650000
# 4098     Honda                  Honda Brio S MT  2013         295000
# 4099    Maruti            Maruti Swift DDiS VDI  2015         480000
# 4100     Honda             Honda City i DTEC SV  2015         575000
#
#       KM_Driven    Fuel       Seller_Type Transmission         Owner
# 540        7104  Petrol  Trustmark Dealer       Manual   First Owner
# ...

# %%
car_price.head()
# Out:
#      Brand                     Model  Year  Selling_Price  KM_Driven    Fuel  \
# 0   Maruti             Maruti 800 AC  2007          60000      70000  Petrol
# 1   Maruti  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2  Hyundai      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3   Datsun    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4    Honda     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   Seller_Type Transmission         Owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
max(car_price['KM_Driven'])
max(car_price['Selling_Price'])
# Out:
# 8900000

# %% [markdown]
# # Lets use a simple dataset as the graph shown for the bigger dataset will be more compilacted

# %%
car_data=pd.read_csv("car-sales.csv")
car_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_data['Price']=car_data['Price'].str.replace(r'[\$\,\.]',"",regex=True)
car_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000

# %%
car_data['Price']=car_data['Price'].str[:-2]
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_data['Sale_date']=pd.date_range("01/01/2025",periods=10)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale_date
# 0  Toyota  White         150043      4   4000 2025-01-01
# 1   Honda    Red          87899      4   5000 2025-01-02
# 2  Toyota   Blue          32549      3   7000 2025-01-03
# 3     BMW  Black          11179      5  22000 2025-01-04
# 4  Nissan  White         213095      4   3500 2025-01-05
# 5  Toyota  Green          99213      4   4500 2025-01-06
# 6   Honda   Blue          45698      4   7500 2025-01-07
# 7   Honda   Blue          54738      4   7000 2025-01-08
# 8  Toyota  White          60000      4   6250 2025-01-09
# 9  Nissan  White          31600      4   9700 2025-01-10

# %%
car_data["Total_sales"]=car_data['Price'].astype(int).cumsum()

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale_date  Total_sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500
# 5  Toyota  Green          99213      4   4500 2025-01-06        46000
# 6   Honda   Blue          45698      4   7500 2025-01-07        53500
# 7   Honda   Blue          54738      4   7000 2025-01-08        60500
# 8  Toyota  White          60000      4   6250 2025-01-09        66750
# 9  Nissan  White          31600      4   9700 2025-01-10        76450

# %%
car_data.plot(x='Sale_date',y='Total_sales')
# Out:
# <Axes: xlabel='Sale_date'>

# %%
car_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale_date  Total_sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500

# %%
car_data['Price']=car_data['Price'].astype(int)
type(car_data['Price'][0])
# Out:
# numpy.int64

# %%
car_data.plot(x="Odometer (KM)",y="Price",kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
car_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale_date  Total_sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500

# %%
car_data.plot(kind="bar",x='Doors',y='Price')
# Out:
# <Axes: xlabel='Doors'>

# %%
plt.barh(list(car_data['Doors']),list(car_data['Price']));

# %%
type(car_data['Odometer (KM)'][0])
# Out:
# numpy.int64

# %%
car_data.plot(kind="bar",y='Odometer (KM)',x='Make')
# Out:
# <Axes: xlabel='Make'>

# %%
car_data['Odometer (KM)'].plot(kind='hist');

# %%
heart_disease=pd.read_csv("heart_disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
heart_disease['age'].plot.hist();

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
over_50_df=heart_disease[heart_disease['age']>50]
over_50_df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
# 5   55    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
#
#    caa  thall  output
# 0    0      1       1
# 3    0      2       1
# 4    0      2       1
# 5    0      1       1
# 6    0      2       1

# %%
# Lets Create some subplots 
fig, ax=plt.subplots(figsize=(8,3))
scatter=ax.scatter(over_50_df['age'],over_50_df['chol'],c=over_50_df['output']);
ax.set(title='Heart Disease and Cholestrol Levels',
      xlabel='Age',
      ylabel='Cholestrol Level');
ax.legend(*scatter.legend_elements(),title='Target')
ax.axhline(over_50_df['chol'].mean(),linestyle="--");

# %% [markdown]
# # Lets  now go for OO Matlotlib plotting as recommended by documentation

# %%
# Going for some subplots now 
fig,(ax1,ax2)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(8,8),
                          sharex=True)
scatter=ax1.scatter(x=over_50_df['age'],
                   y=over_50_df['chol'],
                   c=over_50_df['output'],
                   cmap="winter")
ax1.set(title='Heart Disease and Cholestrol Level',
       xlabel='Age',
       ylabel='Chol')
ax1.set_xlim([45,80]);
ax1.legend(*scatter.legend_elements(),title='Target')
ax1.axhline(over_50_df['chol'].mean(),linestyle='--')


scatter=ax2.scatter(x=over_50_df["age"],
                    y=over_50_df['thalachh'],
                    c=over_50_df['output'],
                   cmap='Dark2')
ax2.set(title='Heart Disease and Max Heart Rate',
       xlabel='Age',
       ylabel='Max Heart Rate')
ax2.set_ylim([60,210])
ax2.legend(*scatter.legend_elements(),title='Target')
ax2.axhline(over_50_df['thalachh'].mean())

fig.suptitle("Heart Disease Analysis");

# %% [markdown]
# # More Customization

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
plt.style.use("ggplot")  # you can use anyone you like
plt.plot(heart_disease['chol'])

# %%
# save figure using 
fig.savefig("sample_image.png")
